# %% [markdown]
# <a href="https://colab.research.google.com/github/Riti740/-ITPR_LAB-project-synopsis-of-food-Management-System-/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# program to display even  factors of a number
num=int (input("Enter a number "))
print("Even factors of", num,"are")
 for i in range(1,num+1)
 if num%i==0 and i%2==0:
  print(i)
